# %% [markdown]
# # [Deep Learning](https://www.cc.gatech.edu/~hays/compvision/proj6/)

# %% [markdown]
# ## Setup

# %%
# %matplotlib notebook
# %load_ext autoreload
# %autoreload 2
import cv2
import numpy as np
import random
import torch.nn as nn
import torch.optim as optim
import os.path as osp
import matplotlib.pyplot as plt
from utils import *
import student_code as sc
from torchvision.models import alexnet

data_path = osp.join('../data', '15SceneData')
num_classes = 15

# If you have a good Nvidia GPU with an appropriate environment, 
# try setting the use_GPU flag to True. The environment provided does
# not support GPUs. Now that we will not provide any support for GPU
# computation in this project. Please also note that 
# we will evaluate your implementations only using CPU mode, so even if
# you use a GPU, make sure your code runs in the CPU mode and using the
# environment we provided. 
use_GPU = False
if use_GPU:
    from utils_gpu import *

# %% [markdown]
# To train a network in PyTorch, we need 4 components:
# 1. Dataset - an object which can load the data and labels given an index.
# 2. Model - an object that contains the network architecture definition.
# 3. Loss function - a function that measures how far the network output is from the ground truth label.
# 4. Optimizer - an object that optimizes the network parameters to reduce the loss value.

# %% [markdown]
# This project has two main parts. In Part 1, you will train a deep network from scratch. In Part 2, you will "fine-tune" a trained network.

# %% [markdown]
# ## Part 0. Warm up! Training a Deep Network from Scratch

# %%
# Fix random seeds so that results will be reproducible
set_seed(0, use_GPU)

# %% [markdown]
# You do not need to code anything for this part. You will simply run the code we provided, but we want you to report the result you got. This section will also familiarize you with the steps of training a deep network from scratch.

# %%
# Training parameters.
input_size = (64, 64)
RGB = False  
base_lr = 1e-2  # may try a smaller lr if not using batch norm
weight_decay = 5e-4
momentum = 0.9

# %% [markdown]
# We will first create our datasets, by calling the create_datasets function from the student_code. This function returns a seperate dataset loader for both the training and the testing/validation dataset. Each dataset loader is then used load the datasets after appling some pre-processing transforms. In Part 1. you will be asked to add a few more pre-processing transforms to the dataset loaders by modifying this function.

# %%
# Create the training and testing datasets.
train_dataset, test_dataset = sc.create_datasets(data_path=data_path, input_size=input_size, rgb=RGB)
assert test_dataset.classes == train_dataset.classes
# Out:
# Computing pixel mean and stdev...
# Batch 0 / 30
# Batch 20 / 30
# Done, mean =
# [0.45579668]
# std =
# [0.23624939]
# Computing pixel mean and stdev...
# Batch 0 / 60
# Batch 20 / 60
# Batch 40 / 60
# Done, mean =
# [0.45517009]
# std =
# [0.2350788]

# %% [markdown]
# Now we will create our network model using the SimpleNet class from the student_code. The implementation provided in SimpleNet class gives you a basic network. In Part 1. you will be asked to add a few more layers to this network.

# %%
# Create the network model.
model = sc.SimpleNet(num_classes=num_classes, rgb=False, verbose=False)
if use_GPU:
    model = model.cuda()
print(model)
# Out:
# SimpleNet(
#   (features): Sequential(
#     (0): Conv2d(1, 10, kernel_size=(9, 9), stride=(1, 1), bias=False)
#     (1): MaxPool2d(kernel_size=7, stride=7, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU()
#   )
#   (classifier): Conv2d(10, 15, kernel_size=(8, 8), stride=(1, 1))
# )

# %% [markdown]
# Next we will create the loss function and the optimizer.

# %%
# Create the loss function.
# see http://pytorch.org/docs/0.3.0/nn.html#loss-functions for a list of available loss functions
loss_function = nn.CrossEntropyLoss()

# %%
# Create the optimizer and a learning rate scheduler
optimizer = optim.SGD(params=model.parameters(), lr=base_lr, weight_decay=weight_decay, momentum=momentum)
# Currently a simple step scheduler.
# See http://pytorch.org/docs/0.3.0/optim.html#how-to-adjust-learning-rate for various LR schedulers
# and how to use them
lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=60, gamma=0.1)

# %% [markdown]
# Finally we are ready to train our network! We will start a local server to see the training progress of our network. Open a new terminal and activate the environment for this project. Then run the following command: ***"python -m visdom.server"***. This will start a local server. The terminal output should give out a link like: "http://localhost:8097". Open this link in your browser. After you run the following block, visit this link again, and you will be able to see graphs showing the progress of your training! If you do not see any graphs, select Part 1 on the top left bar where is says Environment (only select Part 1, do not check main or Part 2).

# %%
# train the network!
params = {'n_epochs': 100, 'batch_size': 50, 'experiment': 'part1'}
trainer = Trainer(train_dataset, test_dataset, model, loss_function, optimizer, lr_scheduler, params)
best_prec1 = trainer.train_val()
print('Best top-1 Accuracy = {:4.3f}'.format(best_prec1))
#Best so far: 36.832 (included in report)
# Out:
# ---------------------------------------
# Experiment: part1
# resume_optim: True
# experiment: part1
# checkpoint_file: None
# num_workers: 4
# shuffle: True
# batch_size: 50
# print_freq: 100
# n_epochs: 100
# do_val: True
# val_freq: 1
# ---------------------------------------
# part1 Epoch 0 / 100
# train part1: batch 0/29, loss 0.519, top-1 accuracy 86.000, top-5 accuracy 96.000
# train part1: loss 0.419282
# val part1: batch 0/59, loss 4.863, top-1 accuracy 18.000, top-5 accuracy 46.000
# val part1: loss 2.913104
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 1 / 100
# train part1: batch 0/29, loss 0.448, top-1 accuracy 88.000, top-5 accuracy 100.000
# train part1: loss 0.417710
# val part1: batch 0/59, loss 4.490, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 2.935968
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 2 / 100
# train part1: batch 0/29, loss 0.451, top-1 accuracy 94.000, top-5 accuracy 98.000
# train part1: loss 0.416379
# val part1: batch 0/59, loss 4.483, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 2.937033
# Checkpoint saved
# part1 Epoch 3 / 100
# train part1: batch 0/29, loss 0.470, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part1: loss 0.414450
# val part1: batch 0/59, loss 4.422, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 2.955456
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 4 / 100
# train part1: batch 0/29, loss 0.350, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.412229
# val part1: batch 0/59, loss 4.356, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 2.959323
# Checkpoint saved
# part1 Epoch 5 / 100
# train part1: batch 0/29, loss 0.352, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.409693
# val part1: batch 0/59, loss 4.330, top-1 accuracy 18.000, top-5 accuracy 60.000
# val part1: loss 2.954168
# Checkpoint saved
# part1 Epoch 6 / 100
# train part1: batch 0/29, loss 0.421, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.409210
# val part1: batch 0/59, loss 4.655, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 2.935130
# Checkpoint saved
# part1 Epoch 7 / 100
# train part1: batch 0/29, loss 0.388, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.406561
# val part1: batch 0/59, loss 4.291, top-1 accuracy 18.000, top-5 accuracy 60.000
# val part1: loss 2.961850
# Checkpoint saved
# part1 Epoch 8 / 100
# train part1: batch 0/29, loss 0.374, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.405273
# val part1: batch 0/59, loss 4.546, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 2.971480
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 9 / 100
# train part1: batch 0/29, loss 0.311, top-1 accuracy 98.000, top-5 accuracy 100.000
# train part1: loss 0.407294
# val part1: batch 0/59, loss 4.848, top-1 accuracy 18.000, top-5 accuracy 48.000
# val part1: loss 2.957511
# Checkpoint saved
# part1 Epoch 10 / 100
# train part1: batch 0/29, loss 0.446, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part1: loss 0.406451
# val part1: batch 0/59, loss 4.550, top-1 accuracy 18.000, top-5 accuracy 54.000
# val part1: loss 2.968662
# Checkpoint saved
# part1 Epoch 11 / 100
# train part1: batch 0/29, loss 0.285, top-1 accuracy 98.000, top-5 accuracy 100.000
# train part1: loss 0.407637
# val part1: batch 0/59, loss 4.789, top-1 accuracy 18.000, top-5 accuracy 52.000
# val part1: loss 2.972019
# Checkpoint saved
# part1 Epoch 12 / 100
# train part1: batch 0/29, loss 0.417, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part1: loss 0.400747
# val part1: batch 0/59, loss 4.321, top-1 accuracy 18.000, top-5 accuracy 62.000
# val part1: loss 2.980195
# Checkpoint saved
# part1 Epoch 13 / 100
# train part1: batch 0/29, loss 0.252, top-1 accuracy 98.000, top-5 accuracy 100.000
# train part1: loss 0.398858
# val part1: batch 0/59, loss 4.623, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 2.989576
# Checkpoint saved
# part1 Epoch 14 / 100
# train part1: batch 0/29, loss 0.383, top-1 accuracy 88.000, top-5 accuracy 100.000
# train part1: loss 0.403945
# val part1: batch 0/59, loss 4.612, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 2.976237
# Checkpoint saved
# part1 Epoch 15 / 100
# train part1: batch 0/29, loss 0.361, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.395207
# val part1: batch 0/59, loss 4.556, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 2.985899
# Checkpoint saved
# part1 Epoch 16 / 100
# train part1: batch 0/29, loss 0.354, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.401063
# val part1: batch 0/59, loss 4.446, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 3.001155
# Checkpoint saved
# part1 Epoch 17 / 100
# train part1: batch 0/29, loss 0.433, top-1 accuracy 88.000, top-5 accuracy 100.000
# train part1: loss 0.396626
# val part1: batch 0/59, loss 4.618, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 2.999258
# Checkpoint saved
# part1 Epoch 18 / 100
# train part1: batch 0/29, loss 0.485, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part1: loss 0.391138
# val part1: batch 0/59, loss 4.653, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.009536
# Checkpoint saved
# part1 Epoch 19 / 100
# train part1: batch 0/29, loss 0.332, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.390139
# val part1: batch 0/59, loss 4.731, top-1 accuracy 18.000, top-5 accuracy 54.000
# val part1: loss 3.001148
# Checkpoint saved
# part1 Epoch 20 / 100
# train part1: batch 0/29, loss 0.437, top-1 accuracy 90.000, top-5 accuracy 98.000
# train part1: loss 0.378126
# val part1: batch 0/59, loss 4.656, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 2.997759
# Checkpoint saved
# part1 Epoch 21 / 100
# train part1: batch 0/29, loss 0.432, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.374345
# val part1: batch 0/59, loss 4.621, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 2.997976
# Checkpoint saved
# part1 Epoch 22 / 100
# train part1: batch 0/29, loss 0.392, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.373701
# val part1: batch 0/59, loss 4.585, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 2.999000
# Checkpoint saved
# part1 Epoch 23 / 100
# train part1: batch 0/29, loss 0.390, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.373683
# val part1: batch 0/59, loss 4.607, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 2.998409
# Checkpoint saved
# part1 Epoch 24 / 100
# train part1: batch 0/29, loss 0.396, top-1 accuracy 96.000, top-5 accuracy 96.000
# train part1: loss 0.373482
# val part1: batch 0/59, loss 4.611, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 2.998877
# Checkpoint saved
# part1 Epoch 25 / 100
# train part1: batch 0/29, loss 0.298, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.373432
# val part1: batch 0/59, loss 4.594, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 2.998007
# Checkpoint saved
# part1 Epoch 26 / 100
# train part1: batch 0/29, loss 0.339, top-1 accuracy 92.000, top-5 accuracy 98.000
# train part1: loss 0.373125
# val part1: batch 0/59, loss 4.651, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 2.998479
# Checkpoint saved
# part1 Epoch 27 / 100
# train part1: batch 0/29, loss 0.334, top-1 accuracy 98.000, top-5 accuracy 100.000
# train part1: loss 0.372880
# val part1: batch 0/59, loss 4.583, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.001265
# Checkpoint saved
# part1 Epoch 28 / 100
# train part1: batch 0/29, loss 0.409, top-1 accuracy 92.000, top-5 accuracy 98.000
# train part1: loss 0.373125
# val part1: batch 0/59, loss 4.627, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 2.998521
# Checkpoint saved
# part1 Epoch 29 / 100
# train part1: batch 0/29, loss 0.293, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.372535
# val part1: batch 0/59, loss 4.574, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 3.001363
# Checkpoint saved
# part1 Epoch 30 / 100
# train part1: batch 0/29, loss 0.303, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.372699
# val part1: batch 0/59, loss 4.628, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 2.999742
# Checkpoint saved
# part1 Epoch 31 / 100
# train part1: batch 0/29, loss 0.410, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.372401
# val part1: batch 0/59, loss 4.629, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 3.001126
# Checkpoint saved
# part1 Epoch 32 / 100
# train part1: batch 0/29, loss 0.316, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.372172
# val part1: batch 0/59, loss 4.624, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 3.001546
# Checkpoint saved
# part1 Epoch 33 / 100
# train part1: batch 0/29, loss 0.473, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part1: loss 0.372061
# val part1: batch 0/59, loss 4.598, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.001674
# Checkpoint saved
# part1 Epoch 34 / 100
# train part1: batch 0/29, loss 0.330, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.371917
# val part1: batch 0/59, loss 4.592, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 3.003110
# Checkpoint saved
# part1 Epoch 35 / 100
# train part1: batch 0/29, loss 0.432, top-1 accuracy 94.000, top-5 accuracy 98.000
# train part1: loss 0.371534
# val part1: batch 0/59, loss 4.604, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.004440
# Checkpoint saved
# part1 Epoch 36 / 100
# train part1: batch 0/29, loss 0.364, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.371548
# val part1: batch 0/59, loss 4.663, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 3.001310
# Checkpoint saved
# part1 Epoch 37 / 100
# train part1: batch 0/29, loss 0.379, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.371359
# val part1: batch 0/59, loss 4.596, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.004525
# Checkpoint saved
# part1 Epoch 38 / 100
# train part1: batch 0/29, loss 0.350, top-1 accuracy 96.000, top-5 accuracy 98.000
# train part1: loss 0.371437
# val part1: batch 0/59, loss 4.643, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.004981
# Checkpoint saved
# part1 Epoch 39 / 100
# train part1: batch 0/29, loss 0.436, top-1 accuracy 90.000, top-5 accuracy 96.000
# train part1: loss 0.371616
# val part1: batch 0/59, loss 4.586, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 3.004099
# Checkpoint saved
# part1 Epoch 40 / 100
# train part1: batch 0/29, loss 0.231, top-1 accuracy 98.000, top-5 accuracy 100.000
# train part1: loss 0.370566
# val part1: batch 0/59, loss 4.647, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 3.004058
# Checkpoint saved
# part1 Epoch 41 / 100
# train part1: batch 0/29, loss 0.351, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.370589
# val part1: batch 0/59, loss 4.638, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 3.005265
# Checkpoint saved
# part1 Epoch 42 / 100
# train part1: batch 0/29, loss 0.390, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.370739
# val part1: batch 0/59, loss 4.631, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 3.005371
# Checkpoint saved
# part1 Epoch 43 / 100
# train part1: batch 0/29, loss 0.373, top-1 accuracy 90.000, top-5 accuracy 98.000
# train part1: loss 0.370342
# val part1: batch 0/59, loss 4.608, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 3.004023
# Checkpoint saved
# part1 Epoch 44 / 100
# train part1: batch 0/29, loss 0.468, top-1 accuracy 92.000, top-5 accuracy 98.000
# train part1: loss 0.370220
# val part1: batch 0/59, loss 4.601, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 3.006831
# Checkpoint saved
# part1 Epoch 45 / 100
# train part1: batch 0/29, loss 0.426, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.369851
# val part1: batch 0/59, loss 4.647, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.006687
# Checkpoint saved
# part1 Epoch 46 / 100
# train part1: batch 0/29, loss 0.392, top-1 accuracy 88.000, top-5 accuracy 100.000
# train part1: loss 0.369637
# val part1: batch 0/59, loss 4.608, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.006886
# Checkpoint saved
# part1 Epoch 47 / 100
# train part1: batch 0/29, loss 0.268, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.369642
# val part1: batch 0/59, loss 4.629, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.007818
# Checkpoint saved
# part1 Epoch 48 / 100
# train part1: batch 0/29, loss 0.356, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.369445
# val part1: batch 0/59, loss 4.636, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.008251
# Checkpoint saved
# part1 Epoch 49 / 100
# train part1: batch 0/29, loss 0.354, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.369465
# val part1: batch 0/59, loss 4.598, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 3.009344
# Checkpoint saved
# part1 Epoch 50 / 100
# train part1: batch 0/29, loss 0.324, top-1 accuracy 98.000, top-5 accuracy 100.000
# train part1: loss 0.369423
# val part1: batch 0/59, loss 4.639, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 3.006923
# Checkpoint saved
# part1 Epoch 51 / 100
# train part1: batch 0/29, loss 0.421, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.369316
# val part1: batch 0/59, loss 4.599, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.011146
# Checkpoint saved
# part1 Epoch 52 / 100
# train part1: batch 0/29, loss 0.394, top-1 accuracy 96.000, top-5 accuracy 98.000
# train part1: loss 0.368667
# val part1: batch 0/59, loss 4.625, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.009462
# Checkpoint saved
# part1 Epoch 53 / 100
# train part1: batch 0/29, loss 0.338, top-1 accuracy 98.000, top-5 accuracy 100.000
# train part1: loss 0.368662
# val part1: batch 0/59, loss 4.624, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.009915
# Checkpoint saved
# part1 Epoch 54 / 100
# train part1: batch 0/29, loss 0.399, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part1: loss 0.368347
# val part1: batch 0/59, loss 4.627, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.010587
# Checkpoint saved
# part1 Epoch 55 / 100
# train part1: batch 0/29, loss 0.354, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.368235
# val part1: batch 0/59, loss 4.642, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 3.009502
# Checkpoint saved
# part1 Epoch 56 / 100
# train part1: batch 0/29, loss 0.426, top-1 accuracy 88.000, top-5 accuracy 100.000
# train part1: loss 0.368200
# val part1: batch 0/59, loss 4.631, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.010121
# Checkpoint saved
# part1 Epoch 57 / 100
# train part1: batch 0/29, loss 0.288, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.368020
# val part1: batch 0/59, loss 4.622, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.012189
# Checkpoint saved
# part1 Epoch 58 / 100
# train part1: batch 0/29, loss 0.501, top-1 accuracy 86.000, top-5 accuracy 98.000
# train part1: loss 0.368410
# val part1: batch 0/59, loss 4.618, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.013627
# Checkpoint saved
# part1 Epoch 59 / 100
# train part1: batch 0/29, loss 0.420, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.367652
# val part1: batch 0/59, loss 4.677, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 3.010639
# Checkpoint saved
# part1 Epoch 60 / 100
# train part1: batch 0/29, loss 0.287, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.367628
# val part1: batch 0/59, loss 4.608, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.011713
# Checkpoint saved
# part1 Epoch 61 / 100
# train part1: batch 0/29, loss 0.354, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.367194
# val part1: batch 0/59, loss 4.625, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 3.013863
# Checkpoint saved
# part1 Epoch 62 / 100
# train part1: batch 0/29, loss 0.324, top-1 accuracy 94.000, top-5 accuracy 98.000
# train part1: loss 0.367064
# val part1: batch 0/59, loss 4.673, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 3.012280
# Checkpoint saved
# part1 Epoch 63 / 100
# train part1: batch 0/29, loss 0.235, top-1 accuracy 98.000, top-5 accuracy 100.000
# train part1: loss 0.366889
# val part1: batch 0/59, loss 4.633, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.014991
# Checkpoint saved
# part1 Epoch 64 / 100
# train part1: batch 0/29, loss 0.317, top-1 accuracy 98.000, top-5 accuracy 100.000
# train part1: loss 0.367052
# val part1: batch 0/59, loss 4.576, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.016247
# Checkpoint saved
# part1 Epoch 65 / 100
# train part1: batch 0/29, loss 0.256, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.366855
# val part1: batch 0/59, loss 4.675, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 3.012013
# Checkpoint saved
# part1 Epoch 66 / 100
# train part1: batch 0/29, loss 0.310, top-1 accuracy 98.000, top-5 accuracy 100.000
# train part1: loss 0.366448
# val part1: batch 0/59, loss 4.628, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.014980
# Checkpoint saved
# part1 Epoch 67 / 100
# train part1: batch 0/29, loss 0.385, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.366347
# val part1: batch 0/59, loss 4.629, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.015996
# Checkpoint saved
# part1 Epoch 68 / 100
# train part1: batch 0/29, loss 0.356, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.366294
# val part1: batch 0/59, loss 4.651, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 3.015872
# Checkpoint saved
# part1 Epoch 69 / 100
# train part1: batch 0/29, loss 0.459, top-1 accuracy 90.000, top-5 accuracy 98.000
# train part1: loss 0.366306
# val part1: batch 0/59, loss 4.639, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.015138
# Checkpoint saved
# part1 Epoch 70 / 100
# train part1: batch 0/29, loss 0.367, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.366120
# val part1: batch 0/59, loss 4.652, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 3.016936
# Checkpoint saved
# part1 Epoch 71 / 100
# train part1: batch 0/29, loss 0.343, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.365787
# val part1: batch 0/59, loss 4.653, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 3.017548
# Checkpoint saved
# part1 Epoch 72 / 100
# train part1: batch 0/29, loss 0.379, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.365583
# val part1: batch 0/59, loss 4.681, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 3.015006
# Checkpoint saved
# part1 Epoch 73 / 100
# train part1: batch 0/29, loss 0.318, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.365445
# val part1: batch 0/59, loss 4.628, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.018358
# Checkpoint saved
# part1 Epoch 74 / 100
# train part1: batch 0/29, loss 0.467, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.365238
# val part1: batch 0/59, loss 4.620, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 3.017509
# Checkpoint saved
# part1 Epoch 75 / 100
# train part1: batch 0/29, loss 0.335, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.365350
# val part1: batch 0/59, loss 4.621, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.018289
# Checkpoint saved
# part1 Epoch 76 / 100
# train part1: batch 0/29, loss 0.309, top-1 accuracy 94.000, top-5 accuracy 98.000
# train part1: loss 0.365383
# val part1: batch 0/59, loss 4.614, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.021781
# Checkpoint saved
# part1 Epoch 77 / 100
# train part1: batch 0/29, loss 0.389, top-1 accuracy 94.000, top-5 accuracy 98.000
# train part1: loss 0.364784
# val part1: batch 0/59, loss 4.669, top-1 accuracy 18.000, top-5 accuracy 56.000
# val part1: loss 3.017611
# Checkpoint saved
# part1 Epoch 78 / 100
# train part1: batch 0/29, loss 0.317, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.364906
# val part1: batch 0/59, loss 4.622, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.020810
# Checkpoint saved
# part1 Epoch 79 / 100
# train part1: batch 0/29, loss 0.333, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.364765
# val part1: batch 0/59, loss 4.647, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.020510
# Checkpoint saved
# part1 Epoch 80 / 100
# train part1: batch 0/29, loss 0.369, top-1 accuracy 96.000, top-5 accuracy 98.000
# train part1: loss 0.363235
# val part1: batch 0/59, loss 4.649, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.020306
# Checkpoint saved
# part1 Epoch 81 / 100
# train part1: batch 0/29, loss 0.391, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.363203
# val part1: batch 0/59, loss 4.651, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.020361
# Checkpoint saved
# part1 Epoch 82 / 100
# train part1: batch 0/29, loss 0.481, top-1 accuracy 90.000, top-5 accuracy 98.000
# train part1: loss 0.363173
# val part1: batch 0/59, loss 4.648, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.020464
# Checkpoint saved
# part1 Epoch 83 / 100
# train part1: batch 0/29, loss 0.313, top-1 accuracy 96.000, top-5 accuracy 98.000
# train part1: loss 0.363167
# val part1: batch 0/59, loss 4.648, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.020185
# Checkpoint saved
# part1 Epoch 84 / 100
# train part1: batch 0/29, loss 0.411, top-1 accuracy 92.000, top-5 accuracy 98.000
# train part1: loss 0.363100
# val part1: batch 0/59, loss 4.643, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.020610
# Checkpoint saved
# part1 Epoch 85 / 100
# train part1: batch 0/29, loss 0.403, top-1 accuracy 86.000, top-5 accuracy 100.000
# train part1: loss 0.363124
# val part1: batch 0/59, loss 4.643, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.020555
# Checkpoint saved
# part1 Epoch 86 / 100
# train part1: batch 0/29, loss 0.345, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.363077
# val part1: batch 0/59, loss 4.647, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.020459
# Checkpoint saved
# part1 Epoch 87 / 100
# train part1: batch 0/29, loss 0.318, top-1 accuracy 92.000, top-5 accuracy 98.000
# train part1: loss 0.363085
# val part1: batch 0/59, loss 4.649, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.020051
# Checkpoint saved
# part1 Epoch 88 / 100
# train part1: batch 0/29, loss 0.442, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.363063
# val part1: batch 0/59, loss 4.643, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.020215
# Checkpoint saved
# part1 Epoch 89 / 100
# train part1: batch 0/29, loss 0.362, top-1 accuracy 94.000, top-5 accuracy 100.000
# train part1: loss 0.363061
# val part1: batch 0/59, loss 4.643, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.020201
# Checkpoint saved
# part1 Epoch 90 / 100
# train part1: batch 0/29, loss 0.378, top-1 accuracy 92.000, top-5 accuracy 100.000
# train part1: loss 0.362991
# val part1: batch 0/59, loss 4.643, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.020604
# Checkpoint saved
# part1 Epoch 91 / 100
# train part1: batch 0/29, loss 0.437, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part1: loss 0.362985
# val part1: batch 0/59, loss 4.642, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.020701
# Checkpoint saved
# part1 Epoch 92 / 100
# train part1: batch 0/29, loss 0.290, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.363006
# val part1: batch 0/59, loss 4.644, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.020451
# Checkpoint saved
# part1 Epoch 93 / 100
# train part1: batch 0/29, loss 0.451, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part1: loss 0.362950
# val part1: batch 0/59, loss 4.650, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.020370
# Checkpoint saved
# part1 Epoch 94 / 100
# train part1: batch 0/29, loss 0.244, top-1 accuracy 98.000, top-5 accuracy 100.000
# train part1: loss 0.362957
# val part1: batch 0/59, loss 4.651, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.020229
# Checkpoint saved
# part1 Epoch 95 / 100
# train part1: batch 0/29, loss 0.293, top-1 accuracy 98.000, top-5 accuracy 100.000
# train part1: loss 0.362946
# val part1: batch 0/59, loss 4.645, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.020349
# Checkpoint saved
# part1 Epoch 96 / 100
# train part1: batch 0/29, loss 0.488, top-1 accuracy 86.000, top-5 accuracy 98.000
# train part1: loss 0.362929
# val part1: batch 0/59, loss 4.645, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.020581
# Checkpoint saved
# part1 Epoch 97 / 100
# train part1: batch 0/29, loss 0.437, top-1 accuracy 90.000, top-5 accuracy 98.000
# train part1: loss 0.362864
# val part1: batch 0/59, loss 4.641, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.020832
# Checkpoint saved
# part1 Epoch 98 / 100
# train part1: batch 0/29, loss 0.372, top-1 accuracy 94.000, top-5 accuracy 98.000
# train part1: loss 0.362878
# val part1: batch 0/59, loss 4.647, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.020657
# Checkpoint saved
# part1 Epoch 99 / 100
# train part1: batch 0/29, loss 0.231, top-1 accuracy 96.000, top-5 accuracy 100.000
# train part1: loss 0.362833
# val part1: batch 0/59, loss 4.644, top-1 accuracy 18.000, top-5 accuracy 58.000
# val part1: loss 3.020859
# Checkpoint saved
# Best top-1 Accuracy = 36.214

# %% [markdown]
# Expect this code to take around 5 minutes if not using a GPU (which may run in around 3 minutes). Now you are ready to actually modify the functions we used to train our model. Before you move, make sure to record the accuracy of your network from Part 0, and report it in your write up.

# %% [markdown]
# ## Part 1: Modifying the Dataloaders and the Simple Network create_datasets

# %%
# Fix random seeds so that results will be reproducible
set_seed(0, use_GPU)

# %% [markdown]
# Now you will modify the create_datasets function from the student_code. You will add random left-right mirroring and normalization to the transformations applied to the training dataset. You will add normalization to the transformations applied to the testing dataset.

# %%
# Create the training and testing datasets.
train_dataset, test_dataset = sc.create_datasets(data_path=data_path, input_size=input_size, rgb=RGB)
assert test_dataset.classes == train_dataset.classes
# Out:
# Computing pixel mean and stdev...
# Batch 0 / 30
# Batch 20 / 30
# Done, mean =
# [0.45579668]
# std =
# [0.23624939]
# Computing pixel mean and stdev...
# Batch 0 / 60
# Batch 20 / 60
# Batch 40 / 60
# Done, mean =
# [0.45517009]
# std =
# [0.2350788]

# %% [markdown]
# Now you will modify the SimpleNet by adding droppout, batch normalization, and additional convolution/maxpool/relu layers. You should exceed an accuracy of **50%**. Make sure your network passes this threshold, it is required for full credit on this section!
#
# You can also use the following two blocks to determine the stucture of your network.

# %%
# create the network model
model = sc.SimpleNet(num_classes=num_classes, rgb=False, verbose=False)
if use_GPU:
    model = model.cuda()
print(model)
# Out:
# SimpleNet(
#   (features): Sequential(
#     (0): Conv2d(1, 10, kernel_size=(7, 7), stride=(1, 1), bias=False)
#     (1): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): MaxPool2d(kernel_size=4, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (3): ReLU()
#     (4): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (5): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (6): MaxPool2d(kernel_size=3, stride=3, padding=0, dilation=1, ceil_mode=False)
#     (7): ReLU()
#     (8): Dropout(p=0.5)
#   )
#   (classifier): Conv2d(10, 15, kernel_size=(5, 5), stride=(1, 1))
# )

# %%
# Use this block to determine the kernel size of the conv2d layer in the classifier
# first, set the kernel size of that conv2d layer to 1, and run this block
# then, use that size of input to the classifier printed by this block to
# go back and update the kernel size of the conv2d layer in the classifier
# Finally, run this block again and verify that the network output size is a scalar
# Don't forget to re-run the block above every time you update the SimpleNet class!
from torch.autograd import Variable
data, _ = train_dataset[0]
s = data.size()
data = Variable(data.view(1, *s))
if use_GPU:
    data = data.cuda()
out = model(data)
print('Network output size is', out.size())
# Out:
# Network output size is torch.Size([15])

# %% [markdown]
# Next we will create the loss function and the optimizer. You do not have to modify the custom_part1_trainer in student_code if you use the same loss_function, optimizer, scheduler and parameters (n_epoch, batch_size etc.) as provided in this notebook to hit the required threshold of 50% accuracy. If you changed any of these values, it is important that you modify this function in student_code since your submission will be autograded (we are not going to open your notebook).

# %%
# Set up the trainer. You can modify custom_part1_trainer in
# student_copy.py if you want to try different learning settings.
custom_part1_trainer = sc.custom_part1_trainer(model)

if custom_part1_trainer is None:
    # Create the loss function.
    # see http://pytorch.org/docs/0.3.0/nn.html#loss-functions for a list of available loss functions
    loss_function = nn.CrossEntropyLoss()

    # Create the optimizer and a learning rate scheduler.
    optimizer = optim.SGD(params=model.parameters(), lr=base_lr, weight_decay=weight_decay, momentum=momentum)
    # Currently a simple step scheduler, but you can get creative.
    # See http://pytorch.org/docs/0.3.0/optim.html#how-to-adjust-learning-rate for various LR schedulers
    # and how to use them
    lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=60, gamma=0.1)

    params = {'n_epochs': 100, 'batch_size': 50, 'experiment': 'part1'}
    
else:
    if 'loss_function' in custom_part1_trainer:
        loss_function = custom_part1_trainer['loss_function']
    if 'optimizer' in custom_part1_trainer:
        optimizer = custom_part1_trainer['optimizer']
    if 'lr_scheduler' in custom_part1_trainer:
        lr_scheduler = custom_part1_trainer['lr_scheduler']
    if 'params' in custom_part1_trainer:
        params = custom_part1_trainer['params']

# %% [markdown]
# We are ready to train our network! As before, we will start a local server to see the training progress of our network (if you server is already running, you should not start another one). Open a new terminal and activate the environment for this project. Then run the following command: ***"python -m visdom.server"***. This will start a local server. The terminal output should give out a link like: "http://localhost:8097". Open this link in your browser. After you run the following block, visit this link again, and you will be able to see graphs showing the progress of your training! If you do not see any graphs, select Part 1 on the top left bar where is says Environment (only select Part 1, do not check main or Part 2).

# %%
# Train the network!
trainer = Trainer(train_dataset, test_dataset, model, loss_function, optimizer, lr_scheduler, params)
best_prec1 = trainer.train_val()
print('Best top-1 Accuracy = {:4.3f}'.format(best_prec1))

#P1 - 44.054 (jittering)
#P2 - 49.414 (jittering + normalization)
#P3 - 60.335 (jittering + normalization + dropout)
#P4 - 54.908 (jittering + normalization + dropout + deeper model)
#P5 - 59.866 (jittering + normalization + dropout + deeper model + batch normalization)
# Out:
# ---------------------------------------
# Experiment: part1
# val_freq: 1
# checkpoint_file: None
# do_val: True
# num_workers: 4
# batch_size: 50
# n_epochs: 100
# shuffle: True
# print_freq: 100
# resume_optim: True
# experiment: part1
# ---------------------------------------
# part1 Epoch 0 / 100
# train part1: batch 0/29, loss 2.751, top-1 accuracy 8.000, top-5 accuracy 38.000
# train part1: loss 2.614287
# val part1: batch 0/59, loss 1.698, top-1 accuracy 58.000, top-5 accuracy 86.000
# val part1: loss 2.481616
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 1 / 100
# train part1: batch 0/29, loss 2.159, top-1 accuracy 36.000, top-5 accuracy 72.000
# train part1: loss 2.302848
# val part1: batch 0/59, loss 2.359, top-1 accuracy 16.000, top-5 accuracy 56.000
# val part1: loss 2.140824
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 2 / 100
# train part1: batch 0/29, loss 2.332, top-1 accuracy 28.000, top-5 accuracy 64.000
# train part1: loss 2.144364
# val part1: batch 0/59, loss 2.131, top-1 accuracy 24.000, top-5 accuracy 64.000
# val part1: loss 2.108123
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 3 / 100
# train part1: batch 0/29, loss 2.092, top-1 accuracy 26.000, top-5 accuracy 76.000
# train part1: loss 2.023877
# val part1: batch 0/59, loss 1.888, top-1 accuracy 40.000, top-5 accuracy 78.000
# val part1: loss 2.020142
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 4 / 100
# train part1: batch 0/29, loss 1.807, top-1 accuracy 46.000, top-5 accuracy 82.000
# train part1: loss 1.906159
# val part1: batch 0/59, loss 2.220, top-1 accuracy 20.000, top-5 accuracy 66.000
# val part1: loss 1.998340
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 5 / 100
# train part1: batch 0/29, loss 2.204, top-1 accuracy 38.000, top-5 accuracy 70.000
# train part1: loss 1.874394
# val part1: batch 0/59, loss 2.042, top-1 accuracy 20.000, top-5 accuracy 78.000
# val part1: loss 1.804693
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 6 / 100
# train part1: batch 0/29, loss 1.542, top-1 accuracy 52.000, top-5 accuracy 90.000
# train part1: loss 1.846561
# val part1: batch 0/59, loss 1.875, top-1 accuracy 26.000, top-5 accuracy 78.000
# val part1: loss 1.795131
# Checkpoint saved
# part1 Epoch 7 / 100
# train part1: batch 0/29, loss 1.967, top-1 accuracy 38.000, top-5 accuracy 82.000
# train part1: loss 1.797502
# val part1: batch 0/59, loss 1.846, top-1 accuracy 28.000, top-5 accuracy 86.000
# val part1: loss 1.791485
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 8 / 100
# train part1: batch 0/29, loss 1.760, top-1 accuracy 38.000, top-5 accuracy 84.000
# train part1: loss 1.752810
# val part1: batch 0/59, loss 2.431, top-1 accuracy 8.000, top-5 accuracy 60.000
# val part1: loss 1.727988
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 9 / 100
# train part1: batch 0/29, loss 1.801, top-1 accuracy 48.000, top-5 accuracy 74.000
# train part1: loss 1.764805
# val part1: batch 0/59, loss 1.958, top-1 accuracy 26.000, top-5 accuracy 78.000
# val part1: loss 1.702104
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 10 / 100
# train part1: batch 0/29, loss 1.717, top-1 accuracy 44.000, top-5 accuracy 86.000
# train part1: loss 1.694956
# val part1: batch 0/59, loss 2.200, top-1 accuracy 16.000, top-5 accuracy 68.000
# val part1: loss 1.664258
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 11 / 100
# train part1: batch 0/29, loss 1.479, top-1 accuracy 50.000, top-5 accuracy 90.000
# train part1: loss 1.691926
# val part1: batch 0/59, loss 1.858, top-1 accuracy 34.000, top-5 accuracy 84.000
# val part1: loss 1.677195
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 12 / 100
# train part1: batch 0/29, loss 1.376, top-1 accuracy 56.000, top-5 accuracy 92.000
# train part1: loss 1.673116
# val part1: batch 0/59, loss 2.167, top-1 accuracy 14.000, top-5 accuracy 74.000
# val part1: loss 1.679009
# Checkpoint saved
# part1 Epoch 13 / 100
# train part1: batch 0/29, loss 1.836, top-1 accuracy 36.000, top-5 accuracy 86.000
# train part1: loss 1.678190
# val part1: batch 0/59, loss 2.383, top-1 accuracy 16.000, top-5 accuracy 62.000
# val part1: loss 1.632353
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 14 / 100
# train part1: batch 0/29, loss 1.829, top-1 accuracy 38.000, top-5 accuracy 78.000
# train part1: loss 1.668545
# val part1: batch 0/59, loss 2.215, top-1 accuracy 20.000, top-5 accuracy 74.000
# val part1: loss 1.716866
# Checkpoint saved
# part1 Epoch 15 / 100
# train part1: batch 0/29, loss 1.400, top-1 accuracy 50.000, top-5 accuracy 90.000
# train part1: loss 1.679522
# val part1: batch 0/59, loss 2.001, top-1 accuracy 26.000, top-5 accuracy 76.000
# val part1: loss 1.680016
# Checkpoint saved
# part1 Epoch 16 / 100
# train part1: batch 0/29, loss 1.432, top-1 accuracy 52.000, top-5 accuracy 92.000
# train part1: loss 1.623424
# val part1: batch 0/59, loss 2.067, top-1 accuracy 24.000, top-5 accuracy 76.000
# val part1: loss 1.613689
# Checkpoint saved
# part1 Epoch 17 / 100
# train part1: batch 0/29, loss 1.560, top-1 accuracy 50.000, top-5 accuracy 88.000
# train part1: loss 1.603757
# val part1: batch 0/59, loss 1.893, top-1 accuracy 28.000, top-5 accuracy 84.000
# val part1: loss 1.543157
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 18 / 100
# train part1: batch 0/29, loss 1.356, top-1 accuracy 60.000, top-5 accuracy 90.000
# train part1: loss 1.593143
# val part1: batch 0/59, loss 2.150, top-1 accuracy 14.000, top-5 accuracy 76.000
# val part1: loss 1.612821
# Checkpoint saved
# part1 Epoch 19 / 100
# train part1: batch 0/29, loss 1.371, top-1 accuracy 54.000, top-5 accuracy 92.000
# train part1: loss 1.624909
# val part1: batch 0/59, loss 1.711, top-1 accuracy 36.000, top-5 accuracy 90.000
# val part1: loss 1.658657
# Checkpoint saved
# part1 Epoch 20 / 100
# train part1: batch 0/29, loss 1.593, top-1 accuracy 54.000, top-5 accuracy 92.000
# train part1: loss 1.569823
# val part1: batch 0/59, loss 2.199, top-1 accuracy 16.000, top-5 accuracy 66.000
# val part1: loss 1.586113
# Checkpoint saved
# part1 Epoch 21 / 100
# train part1: batch 0/29, loss 1.280, top-1 accuracy 72.000, top-5 accuracy 90.000
# train part1: loss 1.521210
# val part1: batch 0/59, loss 1.696, top-1 accuracy 34.000, top-5 accuracy 90.000
# val part1: loss 1.522530
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 22 / 100
# train part1: batch 0/29, loss 1.748, top-1 accuracy 44.000, top-5 accuracy 76.000
# train part1: loss 1.533887
# val part1: batch 0/59, loss 2.043, top-1 accuracy 24.000, top-5 accuracy 86.000
# val part1: loss 1.574328
# Checkpoint saved
# part1 Epoch 23 / 100
# train part1: batch 0/29, loss 1.478, top-1 accuracy 48.000, top-5 accuracy 90.000
# train part1: loss 1.514028
# val part1: batch 0/59, loss 1.973, top-1 accuracy 24.000, top-5 accuracy 84.000
# val part1: loss 1.613917
# Checkpoint saved
# part1 Epoch 24 / 100
# train part1: batch 0/29, loss 2.029, top-1 accuracy 28.000, top-5 accuracy 78.000
# train part1: loss 1.522815
# val part1: batch 0/59, loss 1.685, top-1 accuracy 28.000, top-5 accuracy 92.000
# val part1: loss 1.553084
# Checkpoint saved
# part1 Epoch 25 / 100
# train part1: batch 0/29, loss 1.348, top-1 accuracy 60.000, top-5 accuracy 88.000
# train part1: loss 1.489970
# val part1: batch 0/59, loss 2.147, top-1 accuracy 10.000, top-5 accuracy 74.000
# val part1: loss 1.464333
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 26 / 100
# train part1: batch 0/29, loss 1.545, top-1 accuracy 46.000, top-5 accuracy 90.000
# train part1: loss 1.511255
# val part1: batch 0/59, loss 1.536, top-1 accuracy 44.000, top-5 accuracy 92.000
# val part1: loss 1.524158
# Checkpoint saved
# part1 Epoch 27 / 100
# train part1: batch 0/29, loss 1.899, top-1 accuracy 36.000, top-5 accuracy 88.000
# train part1: loss 1.499928
# val part1: batch 0/59, loss 2.215, top-1 accuracy 14.000, top-5 accuracy 70.000
# val part1: loss 1.505087
# Checkpoint saved
# part1 Epoch 28 / 100
# train part1: batch 0/29, loss 1.849, top-1 accuracy 46.000, top-5 accuracy 86.000
# train part1: loss 1.499166
# val part1: batch 0/59, loss 1.665, top-1 accuracy 36.000, top-5 accuracy 92.000
# val part1: loss 1.432868
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 29 / 100
# train part1: batch 0/29, loss 1.488, top-1 accuracy 40.000, top-5 accuracy 90.000
# train part1: loss 1.444917
# val part1: batch 0/59, loss 1.842, top-1 accuracy 34.000, top-5 accuracy 84.000
# val part1: loss 1.459057
# Checkpoint saved
# part1 Epoch 30 / 100
# train part1: batch 0/29, loss 1.335, top-1 accuracy 48.000, top-5 accuracy 96.000
# train part1: loss 1.457010
# val part1: batch 0/59, loss 1.946, top-1 accuracy 20.000, top-5 accuracy 88.000
# val part1: loss 1.481050
# Checkpoint saved
# part1 Epoch 31 / 100
# train part1: batch 0/29, loss 1.438, top-1 accuracy 54.000, top-5 accuracy 90.000
# train part1: loss 1.476745
# val part1: batch 0/59, loss 1.598, top-1 accuracy 38.000, top-5 accuracy 92.000
# val part1: loss 1.470819
# Checkpoint saved
# part1 Epoch 32 / 100
# train part1: batch 0/29, loss 1.324, top-1 accuracy 60.000, top-5 accuracy 96.000
# train part1: loss 1.488961
# val part1: batch 0/59, loss 1.866, top-1 accuracy 22.000, top-5 accuracy 82.000
# val part1: loss 1.415109
# Checkpoint saved
# part1 Epoch 33 / 100
# train part1: batch 0/29, loss 1.355, top-1 accuracy 52.000, top-5 accuracy 92.000
# train part1: loss 1.408670
# val part1: batch 0/59, loss 2.281, top-1 accuracy 8.000, top-5 accuracy 72.000
# val part1: loss 1.354949
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 34 / 100
# train part1: batch 0/29, loss 1.361, top-1 accuracy 52.000, top-5 accuracy 94.000
# train part1: loss 1.397050
# val part1: batch 0/59, loss 1.824, top-1 accuracy 24.000, top-5 accuracy 90.000
# val part1: loss 1.445538
# Checkpoint saved
# part1 Epoch 35 / 100
# train part1: batch 0/29, loss 1.714, top-1 accuracy 46.000, top-5 accuracy 82.000
# train part1: loss 1.417974
# val part1: batch 0/59, loss 1.485, top-1 accuracy 46.000, top-5 accuracy 92.000
# val part1: loss 1.424644
# Checkpoint saved
# part1 Epoch 36 / 100
# train part1: batch 0/29, loss 1.097, top-1 accuracy 70.000, top-5 accuracy 92.000
# train part1: loss 1.412610
# val part1: batch 0/59, loss 1.715, top-1 accuracy 36.000, top-5 accuracy 84.000
# val part1: loss 1.385220
# Checkpoint saved
# part1 Epoch 37 / 100
# train part1: batch 0/29, loss 1.479, top-1 accuracy 52.000, top-5 accuracy 88.000
# train part1: loss 1.409502
# val part1: batch 0/59, loss 1.851, top-1 accuracy 36.000, top-5 accuracy 86.000
# val part1: loss 1.497525
# Checkpoint saved
# part1 Epoch 38 / 100
# train part1: batch 0/29, loss 1.112, top-1 accuracy 68.000, top-5 accuracy 96.000
# train part1: loss 1.399455
# val part1: batch 0/59, loss 2.179, top-1 accuracy 12.000, top-5 accuracy 80.000
# val part1: loss 1.445921
# Checkpoint saved
# part1 Epoch 39 / 100
# train part1: batch 0/29, loss 1.529, top-1 accuracy 56.000, top-5 accuracy 84.000
# train part1: loss 1.430035
# val part1: batch 0/59, loss 1.949, top-1 accuracy 24.000, top-5 accuracy 88.000
# val part1: loss 1.426732
# Checkpoint saved
# part1 Epoch 40 / 100
# train part1: batch 0/29, loss 1.342, top-1 accuracy 66.000, top-5 accuracy 86.000
# train part1: loss 1.369748
# val part1: batch 0/59, loss 2.019, top-1 accuracy 26.000, top-5 accuracy 88.000
# val part1: loss 1.486104
# Checkpoint saved
# part1 Epoch 41 / 100
# train part1: batch 0/29, loss 1.442, top-1 accuracy 50.000, top-5 accuracy 94.000
# train part1: loss 1.388921
# val part1: batch 0/59, loss 2.043, top-1 accuracy 20.000, top-5 accuracy 80.000
# val part1: loss 1.362674
# Checkpoint saved
# part1 Epoch 42 / 100
# train part1: batch 0/29, loss 1.417, top-1 accuracy 54.000, top-5 accuracy 90.000
# train part1: loss 1.377946
# val part1: batch 0/59, loss 2.115, top-1 accuracy 20.000, top-5 accuracy 76.000
# val part1: loss 1.401059
# Checkpoint saved
# part1 Epoch 43 / 100
# train part1: batch 0/29, loss 1.401, top-1 accuracy 50.000, top-5 accuracy 94.000
# train part1: loss 1.360143
# val part1: batch 0/59, loss 2.041, top-1 accuracy 24.000, top-5 accuracy 80.000
# val part1: loss 1.422192
# Checkpoint saved
# part1 Epoch 44 / 100
# train part1: batch 0/29, loss 1.424, top-1 accuracy 52.000, top-5 accuracy 94.000
# train part1: loss 1.385424
# val part1: batch 0/59, loss 1.765, top-1 accuracy 38.000, top-5 accuracy 82.000
# val part1: loss 1.435450
# Checkpoint saved
# part1 Epoch 45 / 100
# train part1: batch 0/29, loss 1.443, top-1 accuracy 52.000, top-5 accuracy 88.000
# train part1: loss 1.321020
# val part1: batch 0/59, loss 1.537, top-1 accuracy 44.000, top-5 accuracy 96.000
# val part1: loss 1.396752
# Checkpoint saved
# part1 Epoch 46 / 100
# train part1: batch 0/29, loss 1.125, top-1 accuracy 66.000, top-5 accuracy 94.000
# train part1: loss 1.368853
# val part1: batch 0/59, loss 1.373, top-1 accuracy 48.000, top-5 accuracy 94.000
# val part1: loss 1.399713
# Checkpoint saved
# part1 Epoch 47 / 100
# train part1: batch 0/29, loss 1.671, top-1 accuracy 50.000, top-5 accuracy 86.000
# train part1: loss 1.367322
# val part1: batch 0/59, loss 1.718, top-1 accuracy 36.000, top-5 accuracy 88.000
# val part1: loss 1.422171
# Checkpoint saved
# part1 Epoch 48 / 100
# train part1: batch 0/29, loss 1.283, top-1 accuracy 60.000, top-5 accuracy 92.000
# train part1: loss 1.370927
# val part1: batch 0/59, loss 1.876, top-1 accuracy 24.000, top-5 accuracy 84.000
# val part1: loss 1.366920
# Checkpoint saved
# part1 Epoch 49 / 100
# train part1: batch 0/29, loss 1.471, top-1 accuracy 48.000, top-5 accuracy 86.000
# train part1: loss 1.373291
# val part1: batch 0/59, loss 1.903, top-1 accuracy 24.000, top-5 accuracy 88.000
# val part1: loss 1.405184
# Checkpoint saved
# part1 Epoch 50 / 100
# train part1: batch 0/29, loss 1.342, top-1 accuracy 44.000, top-5 accuracy 94.000
# train part1: loss 1.374050
# val part1: batch 0/59, loss 1.733, top-1 accuracy 38.000, top-5 accuracy 88.000
# val part1: loss 1.379391
# Checkpoint saved
# part1 Epoch 51 / 100
# train part1: batch 0/29, loss 1.484, top-1 accuracy 54.000, top-5 accuracy 94.000
# train part1: loss 1.316166
# val part1: batch 0/59, loss 2.016, top-1 accuracy 18.000, top-5 accuracy 82.000
# val part1: loss 1.377929
# Checkpoint saved
# part1 Epoch 52 / 100
# train part1: batch 0/29, loss 1.239, top-1 accuracy 54.000, top-5 accuracy 92.000
# train part1: loss 1.354429
# val part1: batch 0/59, loss 1.927, top-1 accuracy 20.000, top-5 accuracy 90.000
# val part1: loss 1.333810
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 53 / 100
# train part1: batch 0/29, loss 1.309, top-1 accuracy 58.000, top-5 accuracy 94.000
# train part1: loss 1.348142
# val part1: batch 0/59, loss 1.797, top-1 accuracy 32.000, top-5 accuracy 90.000
# val part1: loss 1.397754
# Checkpoint saved
# part1 Epoch 54 / 100
# train part1: batch 0/29, loss 1.456, top-1 accuracy 48.000, top-5 accuracy 92.000
# train part1: loss 1.331871
# val part1: batch 0/59, loss 1.436, top-1 accuracy 46.000, top-5 accuracy 92.000
# val part1: loss 1.416382
# Checkpoint saved
# part1 Epoch 55 / 100
# train part1: batch 0/29, loss 1.386, top-1 accuracy 60.000, top-5 accuracy 96.000
# train part1: loss 1.324076
# val part1: batch 0/59, loss 1.714, top-1 accuracy 34.000, top-5 accuracy 94.000
# val part1: loss 1.307405
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 56 / 100
# train part1: batch 0/29, loss 1.298, top-1 accuracy 50.000, top-5 accuracy 92.000
# train part1: loss 1.310229
# val part1: batch 0/59, loss 1.909, top-1 accuracy 18.000, top-5 accuracy 90.000
# val part1: loss 1.358079
# Checkpoint saved
# part1 Epoch 57 / 100
# train part1: batch 0/29, loss 1.376, top-1 accuracy 52.000, top-5 accuracy 94.000
# train part1: loss 1.309194
# val part1: batch 0/59, loss 1.573, top-1 accuracy 44.000, top-5 accuracy 96.000
# val part1: loss 1.374846
# Checkpoint saved
# part1 Epoch 58 / 100
# train part1: batch 0/29, loss 1.143, top-1 accuracy 60.000, top-5 accuracy 96.000
# train part1: loss 1.276190
# val part1: batch 0/59, loss 1.925, top-1 accuracy 26.000, top-5 accuracy 88.000
# val part1: loss 1.385480
# Checkpoint saved
# part1 Epoch 59 / 100
# train part1: batch 0/29, loss 1.107, top-1 accuracy 66.000, top-5 accuracy 96.000
# train part1: loss 1.292224
# val part1: batch 0/59, loss 1.405, top-1 accuracy 42.000, top-5 accuracy 98.000
# val part1: loss 1.442317
# Checkpoint saved
# part1 Epoch 60 / 100
# train part1: batch 0/29, loss 1.495, top-1 accuracy 52.000, top-5 accuracy 94.000
# train part1: loss 1.252968
# val part1: batch 0/59, loss 1.707, top-1 accuracy 28.000, top-5 accuracy 94.000
# val part1: loss 1.298674
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 61 / 100
# train part1: batch 0/29, loss 1.051, top-1 accuracy 68.000, top-5 accuracy 90.000
# train part1: loss 1.205219
# val part1: batch 0/59, loss 1.747, top-1 accuracy 28.000, top-5 accuracy 94.000
# val part1: loss 1.287492
# Checkpoint saved
# part1 Epoch 62 / 100
# train part1: batch 0/29, loss 1.157, top-1 accuracy 56.000, top-5 accuracy 96.000
# train part1: loss 1.238643
# val part1: batch 0/59, loss 1.746, top-1 accuracy 28.000, top-5 accuracy 94.000
# val part1: loss 1.284885
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 63 / 100
# train part1: batch 0/29, loss 1.295, top-1 accuracy 50.000, top-5 accuracy 96.000
# train part1: loss 1.221270
# val part1: batch 0/59, loss 1.804, top-1 accuracy 26.000, top-5 accuracy 88.000
# val part1: loss 1.275647
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 64 / 100
# train part1: batch 0/29, loss 1.368, top-1 accuracy 50.000, top-5 accuracy 94.000
# train part1: loss 1.248082
# val part1: batch 0/59, loss 1.797, top-1 accuracy 24.000, top-5 accuracy 88.000
# val part1: loss 1.274571
# Checkpoint saved
# part1 Epoch 65 / 100
# train part1: batch 0/29, loss 1.126, top-1 accuracy 62.000, top-5 accuracy 94.000
# train part1: loss 1.239270
# val part1: batch 0/59, loss 1.828, top-1 accuracy 24.000, top-5 accuracy 84.000
# val part1: loss 1.272355
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 66 / 100
# train part1: batch 0/29, loss 1.001, top-1 accuracy 74.000, top-5 accuracy 94.000
# train part1: loss 1.215346
# val part1: batch 0/59, loss 1.784, top-1 accuracy 26.000, top-5 accuracy 86.000
# val part1: loss 1.272925
# Checkpoint saved
# part1 Epoch 67 / 100
# train part1: batch 0/29, loss 1.350, top-1 accuracy 50.000, top-5 accuracy 96.000
# train part1: loss 1.242006
# val part1: batch 0/59, loss 1.722, top-1 accuracy 30.000, top-5 accuracy 86.000
# val part1: loss 1.280783
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 68 / 100
# train part1: batch 0/29, loss 1.128, top-1 accuracy 58.000, top-5 accuracy 98.000
# train part1: loss 1.220032
# val part1: batch 0/59, loss 1.754, top-1 accuracy 30.000, top-5 accuracy 86.000
# val part1: loss 1.275280
# Checkpoint saved
# part1 Epoch 69 / 100
# train part1: batch 0/29, loss 0.955, top-1 accuracy 70.000, top-5 accuracy 96.000
# train part1: loss 1.227805
# val part1: batch 0/59, loss 1.759, top-1 accuracy 24.000, top-5 accuracy 86.000
# val part1: loss 1.272450
# Checkpoint saved
# part1 Epoch 70 / 100
# train part1: batch 0/29, loss 1.037, top-1 accuracy 62.000, top-5 accuracy 98.000
# train part1: loss 1.208365
# val part1: batch 0/59, loss 1.704, top-1 accuracy 32.000, top-5 accuracy 94.000
# val part1: loss 1.269484
# Checkpoint saved
# part1 Epoch 71 / 100
# train part1: batch 0/29, loss 1.257, top-1 accuracy 62.000, top-5 accuracy 94.000
# train part1: loss 1.179667
# val part1: batch 0/59, loss 1.775, top-1 accuracy 24.000, top-5 accuracy 84.000
# val part1: loss 1.270803
# Checkpoint saved
# part1 Epoch 72 / 100
# train part1: batch 0/29, loss 1.220, top-1 accuracy 66.000, top-5 accuracy 94.000
# train part1: loss 1.201327
# val part1: batch 0/59, loss 1.781, top-1 accuracy 26.000, top-5 accuracy 84.000
# val part1: loss 1.268475
# Checkpoint saved
# part1 Epoch 73 / 100
# train part1: batch 0/29, loss 1.033, top-1 accuracy 60.000, top-5 accuracy 94.000
# train part1: loss 1.198325
# val part1: batch 0/59, loss 1.810, top-1 accuracy 22.000, top-5 accuracy 86.000
# val part1: loss 1.270493
# Checkpoint saved
# part1 Epoch 74 / 100
# train part1: batch 0/29, loss 0.947, top-1 accuracy 72.000, top-5 accuracy 96.000
# train part1: loss 1.166765
# val part1: batch 0/59, loss 1.795, top-1 accuracy 24.000, top-5 accuracy 88.000
# val part1: loss 1.263816
# Checkpoint saved
# part1 Epoch 75 / 100
# train part1: batch 0/29, loss 1.149, top-1 accuracy 54.000, top-5 accuracy 96.000
# train part1: loss 1.175160
# val part1: batch 0/59, loss 1.761, top-1 accuracy 28.000, top-5 accuracy 92.000
# val part1: loss 1.260932
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 76 / 100
# train part1: batch 0/29, loss 1.349, top-1 accuracy 50.000, top-5 accuracy 92.000
# train part1: loss 1.188238
# val part1: batch 0/59, loss 1.724, top-1 accuracy 26.000, top-5 accuracy 94.000
# val part1: loss 1.263389
# Checkpoint saved
# part1 Epoch 77 / 100
# train part1: batch 0/29, loss 0.938, top-1 accuracy 64.000, top-5 accuracy 98.000
# train part1: loss 1.170832
# val part1: batch 0/59, loss 1.815, top-1 accuracy 24.000, top-5 accuracy 84.000
# val part1: loss 1.269980
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 78 / 100
# train part1: batch 0/29, loss 1.074, top-1 accuracy 66.000, top-5 accuracy 96.000
# train part1: loss 1.208639
# val part1: batch 0/59, loss 1.715, top-1 accuracy 28.000, top-5 accuracy 86.000
# val part1: loss 1.274830
# Checkpoint saved
# part1 Epoch 79 / 100
# train part1: batch 0/29, loss 1.250, top-1 accuracy 56.000, top-5 accuracy 90.000
# train part1: loss 1.216864
# val part1: batch 0/59, loss 1.813, top-1 accuracy 24.000, top-5 accuracy 88.000
# val part1: loss 1.265350
# Checkpoint saved
# part1 Epoch 80 / 100
# train part1: batch 0/29, loss 1.148, top-1 accuracy 64.000, top-5 accuracy 96.000
# train part1: loss 1.218626
# val part1: batch 0/59, loss 1.661, top-1 accuracy 30.000, top-5 accuracy 90.000
# val part1: loss 1.266878
# Checkpoint saved
# part1 Epoch 81 / 100
# train part1: batch 0/29, loss 1.142, top-1 accuracy 58.000, top-5 accuracy 94.000
# train part1: loss 1.197506
# val part1: batch 0/59, loss 1.748, top-1 accuracy 24.000, top-5 accuracy 86.000
# val part1: loss 1.277939
# Checkpoint saved
# part1 Epoch 82 / 100
# train part1: batch 0/29, loss 1.208, top-1 accuracy 62.000, top-5 accuracy 94.000
# train part1: loss 1.176260
# val part1: batch 0/59, loss 1.774, top-1 accuracy 28.000, top-5 accuracy 86.000
# val part1: loss 1.257146
# Checkpoint saved
# part1 Epoch 83 / 100
# train part1: batch 0/29, loss 1.294, top-1 accuracy 54.000, top-5 accuracy 94.000
# train part1: loss 1.211722
# val part1: batch 0/59, loss 1.712, top-1 accuracy 28.000, top-5 accuracy 88.000
# val part1: loss 1.274142
# Checkpoint saved
# part1 Epoch 84 / 100
# train part1: batch 0/29, loss 1.144, top-1 accuracy 56.000, top-5 accuracy 96.000
# train part1: loss 1.191993
# val part1: batch 0/59, loss 1.738, top-1 accuracy 26.000, top-5 accuracy 88.000
# val part1: loss 1.258472
# Checkpoint saved
# part1 Epoch 85 / 100
# train part1: batch 0/29, loss 1.148, top-1 accuracy 58.000, top-5 accuracy 98.000
# train part1: loss 1.229711
# val part1: batch 0/59, loss 1.655, top-1 accuracy 30.000, top-5 accuracy 90.000
# val part1: loss 1.261563
# Checkpoint saved
# part1 Epoch 86 / 100
# train part1: batch 0/29, loss 1.115, top-1 accuracy 66.000, top-5 accuracy 98.000
# train part1: loss 1.182379
# val part1: batch 0/59, loss 1.741, top-1 accuracy 28.000, top-5 accuracy 84.000
# val part1: loss 1.271607
# Checkpoint saved
# part1 Epoch 87 / 100
# train part1: batch 0/29, loss 1.513, top-1 accuracy 60.000, top-5 accuracy 86.000
# train part1: loss 1.170397
# val part1: batch 0/59, loss 1.735, top-1 accuracy 24.000, top-5 accuracy 90.000
# val part1: loss 1.259485
# Checkpoint saved
# part1 Epoch 88 / 100
# train part1: batch 0/29, loss 1.359, top-1 accuracy 52.000, top-5 accuracy 96.000
# train part1: loss 1.194357
# val part1: batch 0/59, loss 1.749, top-1 accuracy 24.000, top-5 accuracy 88.000
# val part1: loss 1.258264
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part1 Epoch 89 / 100
# train part1: batch 0/29, loss 1.107, top-1 accuracy 66.000, top-5 accuracy 96.000
# train part1: loss 1.149374
# val part1: batch 0/59, loss 1.666, top-1 accuracy 32.000, top-5 accuracy 92.000
# val part1: loss 1.264170
# Checkpoint saved
# part1 Epoch 90 / 100
# train part1: batch 0/29, loss 1.386, top-1 accuracy 52.000, top-5 accuracy 94.000
# train part1: loss 1.186968
# val part1: batch 0/59, loss 1.754, top-1 accuracy 26.000, top-5 accuracy 90.000
# val part1: loss 1.257238
# Checkpoint saved
# part1 Epoch 91 / 100
# train part1: batch 0/29, loss 1.023, top-1 accuracy 70.000, top-5 accuracy 100.000
# train part1: loss 1.168387
# val part1: batch 0/59, loss 1.823, top-1 accuracy 24.000, top-5 accuracy 82.000
# val part1: loss 1.271501
# Checkpoint saved
# part1 Epoch 92 / 100
# train part1: batch 0/29, loss 1.320, top-1 accuracy 56.000, top-5 accuracy 92.000
# train part1: loss 1.206281
# val part1: batch 0/59, loss 1.736, top-1 accuracy 26.000, top-5 accuracy 88.000
# val part1: loss 1.269161
# Checkpoint saved
# part1 Epoch 93 / 100
# train part1: batch 0/29, loss 1.118, top-1 accuracy 62.000, top-5 accuracy 94.000
# train part1: loss 1.190701
# val part1: batch 0/59, loss 1.738, top-1 accuracy 26.000, top-5 accuracy 86.000
# val part1: loss 1.260168
# Checkpoint saved
# part1 Epoch 94 / 100
# train part1: batch 0/29, loss 1.034, top-1 accuracy 56.000, top-5 accuracy 100.000
# train part1: loss 1.168942
# val part1: batch 0/59, loss 1.661, top-1 accuracy 32.000, top-5 accuracy 90.000
# val part1: loss 1.259962
# Checkpoint saved
# part1 Epoch 95 / 100
# train part1: batch 0/29, loss 1.211, top-1 accuracy 66.000, top-5 accuracy 94.000
# train part1: loss 1.178277
# val part1: batch 0/59, loss 1.777, top-1 accuracy 24.000, top-5 accuracy 86.000
# val part1: loss 1.265139
# Checkpoint saved
# part1 Epoch 96 / 100
# train part1: batch 0/29, loss 1.075, top-1 accuracy 62.000, top-5 accuracy 100.000
# train part1: loss 1.165763
# val part1: batch 0/59, loss 1.758, top-1 accuracy 24.000, top-5 accuracy 88.000
# val part1: loss 1.256746
# Checkpoint saved
# part1 Epoch 97 / 100
# train part1: batch 0/29, loss 1.099, top-1 accuracy 66.000, top-5 accuracy 96.000
# train part1: loss 1.174997
# val part1: batch 0/59, loss 1.702, top-1 accuracy 30.000, top-5 accuracy 90.000
# val part1: loss 1.257786
# Checkpoint saved
# part1 Epoch 98 / 100
# train part1: batch 0/29, loss 1.271, top-1 accuracy 70.000, top-5 accuracy 94.000
# train part1: loss 1.169251
# val part1: batch 0/59, loss 1.817, top-1 accuracy 24.000, top-5 accuracy 84.000
# val part1: loss 1.259090
# Checkpoint saved
# part1 Epoch 99 / 100
# train part1: batch 0/29, loss 1.251, top-1 accuracy 60.000, top-5 accuracy 94.000
# train part1: loss 1.185048
# val part1: batch 0/59, loss 1.729, top-1 accuracy 28.000, top-5 accuracy 90.000
# val part1: loss 1.263505
# Checkpoint saved
# Best top-1 Accuracy = 59.866

# %% [markdown]
# Make sure you get at least 50% accuracy in this section! If you tried different settings than the ones provided to get 50%, you should modify custom_part1_trainer in student code to return a dictionary with your changed settings.

# %% [markdown]
# ## Part 2. Fine-Tuning a Pre-Trained Network

# %%
# Fix random seeds so that results will be reproducible
set_seed(0, use_GPU)

# %% [markdown]
# Training a network from scratch takes a lof of time. Instead of training from scratch, we can take a pre-trained model, and fine tune it for our purposes. This is the goal of Part 2. You will train a pre-trained network, and achieve at least 80% accuracy.

# %%
# training parameters
input_size = (224, 224)
RGB = True
base_lr = 1e-3
weight_decay = 5e-4
momentum = 0.9
backprop_depth = 3

# %%
# Create the training and testing datasets.
train_dataset, test_dataset = sc.create_datasets(data_path=data_path, input_size=input_size, rgb=RGB)
assert test_dataset.classes == train_dataset.classes
# Out:
# Computing pixel mean and stdev...
# Batch 0 / 30
# Batch 20 / 30
# Done, mean =
# [0.45611589 0.45611589 0.45611589]
# std =
# [0.24786406 0.24786406 0.24786406]
# Computing pixel mean and stdev...
# Batch 0 / 60
# Batch 20 / 60
# Batch 40 / 60
# Done, mean =
# [0.45549639 0.45549639 0.45549639]
# std =
# [0.24698076 0.24698076 0.24698076]

# %% [markdown]
# Following block loads a pretrained alexnet.

# %%
# Create the network model.
model = alexnet(pretrained=True)
print(model)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace)
#     (3): Dropout(p=0.5)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %% [markdown]
# Now, you modify call create_part2_model from student code to change alexnet in order to fine tune it. As you can see at https://github.com/pytorch/vision/blob/master/torchvision/models/alexnet.py, and in the model printout above, AlexNet has 2 parts: 'features', which constists of conv layers that extract feature maps from the image, and 'classifier' which consists of FC layers that classify the features. We want to replace the last Linear layer in model.classifier.

# %%
model = sc.create_part2_model(model, num_classes)
if use_GPU:
    model = model.cuda()
print(model)
# Out:
# AlexNet(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(11, 11), stride=(4, 4), padding=(2, 2))
#     (1): ReLU(inplace)
#     (2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 192, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (4): ReLU(inplace)
#     (5): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(192, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace)
#     (8): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU(inplace)
#     (10): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace)
#     (12): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (classifier): Sequential(
#     (0): Dropout(p=0.5)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU(inplace)
#     (3): Dropout(p=0.5)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU(inplace)
#     (6): Linear(in_features=4096, out_features=15, bias=True)
#   )
# )

# %% [markdown]
# Next we will create the loss function and the optimizer. Just as with part 1, if you modify any of the setttings to hit the required accuracy, you must modify custom_part2_trainer function to return a dictionary containing your changes.

# %%
# Set up the trainer. You can modify custom_part2_trainer in
# student_copy.py if you want to try different learning settings.
custom_part2_trainer = sc.custom_part2_trainer(model)

if custom_part2_trainer is None:
    # Create the loss function
    # see http://pytorch.org/docs/0.3.0/nn.html#loss-functions for a list of available loss functions
    loss_function = nn.CrossEntropyLoss()

    # Since we do not want to optimize the whole network, we must extract a list of parameters of interest that will be
    # optimized by the optimizer.
    params_to_optimize = []

    # List of modules in the network
    mods = list(model.features.children()) + list(model.classifier.children())

    # Extract parameters from the last `backprop_depth` modules in the network and collect them in
    # the params_to_optimize list.
    for m in mods[::-1][:backprop_depth]:
        params_to_optimize.extend(list(m.parameters()))

    # Construct the optimizer    
    optimizer = optim.SGD(params=params_to_optimize, lr=base_lr, weight_decay=weight_decay, momentum=momentum)

    # Create a scheduler, currently a simple step scheduler, but you can get creative.
    # See http://pytorch.org/docs/0.3.0/optim.html#how-to-adjust-learning-rate for various LR schedulers
    # and how to use them
    lr_scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=10, gamma=0.1)
    
    params = {'n_epochs': 4, 'batch_size': 10, 'experiment': 'part2'} 
    
else:
    if 'loss_function' in custom_part2_trainer:
        loss_function = custom_part2_trainer['loss_function']
    if 'optimizer' in custom_part2_trainer:
        optimizer = custom_part2_trainer['optimizer']
    if 'lr_scheduler' in custom_part2_trainer:
        lr_scheduler = custom_part2_trainer['lr_scheduler']
    if 'params' in custom_part2_trainer:
        params = custom_part2_trainer['params']

# %% [markdown]
# We are ready to fine tune our network! Just like before, we will start a local server to see the training progress of our network. Open a new terminal and activate the environment for this project. Then run the following command: ***"python -m visdom.server"***. This will start a local server. The terminal output should give out a link like: "http://localhost:8097". Open this link in your browser. After you run the following block, visit this link again, and you will be able to see graphs showing the progress of your training! If you do not see any graphs, select Part 2 on the top left bar where is says Environment (only select Part 2, do not check main or Part 1).

# %%
# Train the network!
trainer = Trainer(train_dataset, test_dataset, model, loss_function, optimizer, lr_scheduler, params)
best_prec1 = trainer.train_val()
print('Best top-1 Accuracy = {:4.3f}'.format(best_prec1))
# Out:
# ---------------------------------------
# Experiment: part2
# batch_size: 10
# do_val: True
# val_freq: 1
# shuffle: True
# num_workers: 4
# n_epochs: 4
# experiment: part2
# checkpoint_file: None
# print_freq: 100
# resume_optim: True
# ---------------------------------------
# part2 Epoch 0 / 4
# train part2: batch 0/149, loss 3.059, top-1 accuracy 0.000, top-5 accuracy 30.000
# train part2: batch 100/149, loss 0.473, top-1 accuracy 70.000, top-5 accuracy 100.000
# train part2: loss 0.873899
# val part2: batch 0/298, loss 0.450, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: batch 100/298, loss 0.426, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: batch 200/298, loss 0.788, top-1 accuracy 70.000, top-5 accuracy 100.000
# val part2: loss 0.477183
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part2 Epoch 1 / 4
# train part2: batch 0/149, loss 0.648, top-1 accuracy 70.000, top-5 accuracy 100.000
# train part2: batch 100/149, loss 0.430, top-1 accuracy 70.000, top-5 accuracy 100.000
# train part2: loss 0.373888
# val part2: batch 0/298, loss 0.174, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: batch 100/298, loss 0.411, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: batch 200/298, loss 0.657, top-1 accuracy 80.000, top-5 accuracy 100.000
# val part2: loss 0.511582
# Checkpoint saved
# part2 Epoch 2 / 4
# train part2: batch 0/149, loss 0.028, top-1 accuracy 100.000, top-5 accuracy 100.000
# train part2: batch 100/149, loss 0.399, top-1 accuracy 80.000, top-5 accuracy 100.000
# train part2: loss 0.249730
# val part2: batch 0/298, loss 0.142, top-1 accuracy 100.000, top-5 accuracy 100.000
# val part2: batch 100/298, loss 0.488, top-1 accuracy 90.000, top-5 accuracy 100.000
# val part2: batch 200/298, loss 0.788, top-1 accuracy 80.000, top-5 accuracy 100.000
# val part2: loss 0.452415
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# part2 Epoch 3 / 4
# train part2: batch 0/149, loss 0.467, top-1 accuracy 90.000, top-5 accuracy 100.000
# train part2: batch 100/149, loss 0.164, top-1 accuracy 100.000, top-5 accuracy 100.000
# train part2: loss 0.176377
# val part2: batch 0/298, loss 0.637, top-1 accuracy 70.000, top-5 accuracy 100.000
# val part2: batch 100/298, loss 0.591, top-1 accuracy 80.000, top-5 accuracy 100.000
# val part2: batch 200/298, loss 0.882, top-1 accuracy 80.000, top-5 accuracy 100.000
# val part2: loss 0.441180
# Checkpoint saved
# BEST TOP1 ACCURACY SO FAR
# Best top-1 Accuracy = 86.030

# %% [markdown]
# Expect this code to take around 10 minutes if not using a GPU (which may run in around 30 seconds). You should hit 80% accuracy.
